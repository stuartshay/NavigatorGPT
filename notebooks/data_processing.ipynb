# %% [markdown]
# # NavigatorGPT

# %%
# imports
import json
import openai
import pkg_resources

PATH_TO_SCRT_JSON = '/home/jovyan/keys/open_ai_key.json'

with open(PATH_TO_SCRT_JSON) as f:
    openai.api_key = json.load(f)['key']

if openai.api_key:
    print("The OpenAI key has been set.")
else:
    print("The OpenAI key has not been set.")

openai_version = pkg_resources.get_distribution("openai").version
print(f"The version of the openai package is {openai_version}")
# Out:
# The OpenAI key has been set.
# The version of the openai package is 0.27.8

# %% [markdown]
# Get Configuration Files

# %% [markdown]
# // Get GraphQL - Schema -- https://navigator-maps-ql-w6zlqlyoma-uk.a.run.app/graphql/
