# %%
# Out:
# ...
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python311\\Scripts\\tqdm.exe' -> 'C:\\Python311\\Scripts\\tqdm.exe.deleteme'
#
#
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 73.6/73.6 kB 1.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 62.6/62.6 kB 128.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.3/78.3 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 320.6/320.6 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 96.6/96.6 kB 275.8 kB/s eta 0:00:00
# ...
#      -------------------------------------- 61.5/61.5 kB 149.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 123.9/123.9 kB 1.8 MB/s eta 0:00:00
# ...
