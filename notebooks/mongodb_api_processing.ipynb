# %% [markdown]
# ## Mongo DB - API Processing

# %%
import json
import pymongo
import pandas as pd
import pprint
import os
from pymongo import MongoClient, UpdateOne
from bson.objectid import ObjectId
from datetime import datetime
import requests
import json

# Load the MongoDB connection string from the JSON file
PATH_TO_SECRET_JSON = '/home/jovyan/keys/mongodb_key.json'
with open(PATH_TO_SECRET_JSON) as f:
    MONGODB_URI = json.load(f)['connection_string']

# Extract the database name from the connection string
db_name = MONGODB_URI.split('/')[-1].split('?')[0]

# Create a MongoDB client using the connection string
if MONGODB_URI:
    client = MongoClient(MONGODB_URI)
    print("The MongoDB client has been initialized.")
else:
    print("Failed to initialize the MongoDB client.")

# Print the version of the pymongo package
pymongo_version = pymongo.__version__
print(f"The version of the pymongo package is {pymongo_version}")

# Connect to the specified MongoDB database and collection
db = client[db_name]
collection = db.attractions
# Out:
# The MongoDB client has been initialized.
# The version of the pymongo package is 4.4.1

# %%
pipeline = [
    {
        "$match": {
            "landmark.lpNumber": { "$exists": True }
        }
    },
    {
        "$project": {
            "_id": 1,
            "title": 1,
            "lpNumber": "$landmark.lpNumber"
        }
    },
    {
        "$sort": {
            "lpNumber": 1
        }
    }
]

cursor = collection.aggregate(pipeline)

df = pd.DataFrame(list(cursor))
df
# Out:
#                            _id  \
# 0     6444d14ee7abb0665474a208
# 1     6455b7e44673c82a34f4ecca
# 2     64bc67c954ab1c604a34d1bc
# 3     54fa99fa5c95965f78def7bf
# 4     560f2c12f89701aedbaebc2c
# ...                        ...
# 1369  64a2f99afc95c50bc98dcf7c
# 1370  64a30238fc95c50bc98dcf82
# 1371  64a300b5fc95c50bc98dcf81
# 1372  64a2fd9dfc95c50bc98dcf7e
# 1373  647ab69e426b0f007933dd15
#
#                                                   title  lpNumber
# 0                          Pieter Claesen Wyckoff House  LP-00001
# 1                                    Commandant's House  LP-00002
# 2                                   U.S. Naval Hospital  LP-00003
# 3                       Audubon Center at the Boathouse  LP-00004
# 4                                   Kingsland Homestead  LP-00005
# ...                                                 ...       ...
# 1369  Gowanus Canal Flushing Tunnel Pumping Station ...  LP-02638
# 1370  Brooklyn Rapid Transit Company (BRT) Central P...  LP-02639
# 1371  Somers Brothers Tinware Factory (later America...  LP-02640
# 1372       Montauk Paint Manufacturing Company Building  LP-02641
# 1373                              Audre Lorde Residence  LP-02642
#
# [1374 rows x 3 columns]

# %%
# Create a directory if it doesn't exist
output_directory = "../downloads/csv/"
os.makedirs(output_directory, exist_ok=True)

# Generate the CSV file name with current date and time
current_datetime = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
csv_filename = f"landmarks_{current_datetime}.csv"  # Fixed a typo here ('lanmarks' -> 'landmarks')
csv_filepath = os.path.join(output_directory, csv_filename)

# Save the DataFrame to a CSV file
df.to_csv(csv_filepath, index=False)

print(f"CSV file saved to: {csv_filepath}")
# Out:
# CSV file saved to: ../downloads/csv/landmarks_2023_09_30_23_56_21.csv

# %%
import requests
import json

# Base API endpoint and headers
url = 'https://microservice-api-w6zlqlyoma-uk.a.run.app/api/v1/FeatureService/attributelookup'
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

# Create an empty list to store the results
results = []

# Loop through the DataFrame
for lp_number in df['lpNumber']:
    # Payload for the API call
    payload = {
        "key": "IndividualLandmarkHistoricDistricts",
        "attributes": [
            {
                "key": "LPNumber",
                "value": lp_number
            }
        ]
    }
    
    # Make the API call
    response = requests.post(url, headers=headers, data=json.dumps(payload))
    
    # Handle the API response
    if response.status_code == 200:
        print(f"API call for {lp_number} was successful!")
        api_data = response.json()
        if api_data:  # Check if the API response has data
            results.append({
                "lpNumber": lp_number,
                "areaName": api_data[0].get("areaName", "")  # Assuming the API returns a list and you're interested in the first item
            })
    else:
        print(f"API call for {lp_number} failed with status code {response.status_code}.")       
            
            
# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Merge the two DataFrames on 'lpNumber'
merged_df = pd.merge(df, results_df, on='lpNumber', how='left')

# Save the merged DataFrame to a CSV file
merged_df.to_csv("../downloads/csv/output_filename.csv", index=False)
# Out:
# API call for LP-00001 was successful!
# API call for LP-00002 was successful!
# API call for LP-00003 was successful!
# API call for LP-00004 was successful!
# API call for LP-00005 failed with status code 500.
# API call for LP-00006 was successful!
# API call for LP-00007 was successful!
# API call for LP-00008 was successful!
# API call for LP-00009 was successful!
# API call for LP-00010 was successful!
# API call for LP-00011 was successful!
# API call for LP-00012 was successful!
# API call for LP-00013 was successful!
# API call for LP-00016 was successful!
# API call for LP-00017 was successful!
# API call for LP-00018 was successful!
# API call for LP-00020 was successful!
# API call for LP-00022 was successful!
# API call for LP-00023 was successful!
# API call for LP-00024 was successful!
# API call for LP-00025 was successful!
# API call for LP-00026 was successful!
# API call for LP-00027 was successful!
# API call for LP-00029 was successful!
# API call for LP-00030 was successful!
# API call for LP-00036 was successful!
# API call for LP-00039 was successful!
# API call for LP-00040 was successful!
# API call for LP-00042 was successful!
# API call for LP-00047 was successful!
# API call for LP-00048 was successful!
# API call for LP-00053 was successful!
# API call for LP-00054 was successful!
# API call for LP-00055 was successful!
# API call for LP-00056 was successful!
# API call for LP-00057 was successful!
# API call for LP-00058 was successful!
# API call for LP-00059 was successful!
# API call for LP-00060 was successful!
# API call for LP-00061 was successful!
# API call for LP-00062 was successful!
# API call for LP-00063 was successful!
# API call for LP-00064 was successful!
# API call for LP-00065 was successful!
# API call for LP-00066 was successful!
# API call for LP-00067 was successful!
# API call for LP-00068 was successful!
# API call for LP-00069 was successful!
# API call for LP-00070 was successful!
# API call for LP-00071 was successful!
# API call for LP-00072 was successful!
# API call for LP-00073 was successful!
# API call for LP-00074 was successful!
# API call for LP-00075 was successful!
# API call for LP-00076 was successful!
# API call for LP-00077 was successful!
# API call for LP-00078 was successful!
# API call for LP-00079 was successful!
# API call for LP-00080 was successful!
# API call for LP-00082 was successful!
# API call for LP-00083 was successful!
# API call for LP-00084 was successful!
# API call for LP-00085 was successful!
# API call for LP-00086 was successful!
# API call for LP-00087 was successful!
# API call for LP-00088 was successful!
# API call for LP-00091 failed with status code 404.
# API call for LP-00092 was successful!
# API call for LP-00093 was successful!
# API call for LP-00094 was successful!
# API call for LP-00095 was successful!
# API call for LP-00096 was successful!
# API call for LP-00097 was successful!
# API call for LP-00098 was successful!
# API call for LP-00101 was successful!
# API call for LP-00108 was successful!
# API call for LP-00109 was successful!
# API call for LP-00110 was successful!
# API call for LP-00112 was successful!
# API call for LP-00113 was successful!
# API call for LP-00114 was successful!
# API call for LP-00115 was successful!
# API call for LP-00116 was successful!
# API call for LP-00117 was successful!
# API call for LP-00118 was successful!
# API call for LP-00119 was successful!
# API call for LP-00121 was successful!
# API call for LP-00124 was successful!
# API call for LP-00125 was successful!
# API call for LP-00126 was successful!
# API call for LP-00127 was successful!
# API call for LP-00128 was successful!
# API call for LP-00129 was successful!
# API call for LP-00131 was successful!
# API call for LP-00133 was successful!
# API call for LP-00135 was successful!
# API call for LP-00136 failed with status code 404.
# API call for LP-00138 was successful!
# API call for LP-00139 was successful!
# API call for LP-00141 was successful!
# API call for LP-00142 was successful!
# API call for LP-00143 was successful!
# API call for LP-00144 was successful!
# API call for LP-00145 was successful!
# API call for LP-00146 was successful!
# API call for LP-00147 was successful!
# API call for LP-00148 was successful!
# API call for LP-00149 was successful!
# API call for LP-00152 was successful!
# API call for LP-00153 was successful!
# API call for LP-00154 was successful!
# API call for LP-00155 was successful!
# API call for LP-00156 was successful!
# API call for LP-00160 was successful!
# API call for LP-00161 was successful!
# API call for LP-00162 was successful!
# API call for LP-00163 was successful!
# API call for LP-00164 was successful!
# API call for LP-00165 was successful!
# API call for LP-00167 was successful!
# API call for LP-00168 was successful!
# API call for LP-00169 was successful!
# API call for LP-00170 was successful!
# API call for LP-00170E was successful!
# API call for LP-00171 was successful!
# API call for LP-00172 was successful!
# API call for LP-00173 was successful!
# API call for LP-00175 was successful!
# API call for LP-00176 was successful!
# API call for LP-00177 was successful!
# API call for LP-00179 was successful!
# API call for LP-00181 was successful!
# API call for LP-00183 was successful!
# API call for LP-00184 was successful!
# API call for LP-00186 failed with status code 404.
# API call for LP-00187 was successful!
# API call for LP-00192 was successful!
# API call for LP-00193 was successful!
# API call for LP-00196 was successful!
# API call for LP-00201 was successful!
# API call for LP-00202 was successful!
# API call for LP-00203 was successful!
# API call for LP-00204 was successful!
# API call for LP-00208 was successful!
# API call for LP-00209 was successful!
# API call for LP-00210 was successful!
# API call for LP-00211 was successful!
# API call for LP-00212 was successful!
# API call for LP-00215 was successful!
# API call for LP-00216 was successful!
# API call for LP-00217 was successful!
# API call for LP-00218 was successful!
# API call for LP-00219 was successful!
# API call for LP-00222 was successful!
# API call for LP-00223 was successful!
# API call for LP-00226 failed with status code 404.
# API call for LP-00227 was successful!
# API call for LP-00229 was successful!
# API call for LP-00230 was successful!
# API call for LP-00231 was successful!
# API call for LP-00232 was successful!
# API call for LP-00233 was successful!
# API call for LP-00234 was successful!
# API call for LP-00235 was successful!
# API call for LP-00236 was successful!
# API call for LP-00239 was successful!
# API call for LP-00241 was successful!
# API call for LP-00244 was successful!
# API call for LP-00246 was successful!
# API call for LP-00254 was successful!
# API call for LP-00255 was successful!
# API call for LP-00256 was successful!
# API call for LP-00257 was successful!
# API call for LP-00259 was successful!
# API call for LP-00260 was successful!
# API call for LP-00263 was successful!
# API call for LP-00265 was successful!
# API call for LP-00266 was successful!
# API call for LP-00267 was successful!
# API call for LP-00268 was successful!
# API call for LP-00271 was successful!
# API call for LP-00273 was successful!
# API call for LP-00275 was successful!
# API call for LP-00276 was successful!
# API call for LP-00277 was successful!
# API call for LP-00278 was successful!
# API call for LP-00280 was successful!
# API call for LP-00281 was successful!
# API call for LP-00282 was successful!
# API call for LP-00285 was successful!
# API call for LP-00287 was successful!
# API call for LP-00288 was successful!
# API call for LP-00289 was successful!
# API call for LP-00291 was successful!
# API call for LP-00292 was successful!
# API call for LP-00293 was successful!
# API call for LP-00294 was successful!
# API call for LP-00297 was successful!
# API call for LP-00298 was successful!
# API call for LP-00300 was successful!
# API call for LP-00301 was successful!
# API call for LP-00303 was successful!
# API call for LP-00304 was successful!
# API call for LP-00305 was successful!
# API call for LP-00306 was successful!
# API call for LP-00307 was successful!
# API call for LP-00308 was successful!
# API call for LP-00309 was successful!
# API call for LP-00312 was successful!
# API call for LP-00313 was successful!
# API call for LP-00317A was successful!
# API call for LP-00319 was successful!
# API call for LP-00330 was successful!
# API call for LP-00331 was successful!
# API call for LP-00332 was successful!
# API call for LP-00334 was successful!
# API call for LP-00338 was successful!
# API call for LP-00339 was successful!
# API call for LP-00341 was successful!
# API call for LP-00342 was successful!
# API call for LP-00344 was successful!
# API call for LP-00345 was successful!
# API call for LP-00346 was successful!
# API call for LP-00350 was successful!
# API call for LP-00357 was successful!
# API call for LP-00361 was successful!
# API call for LP-00364 was successful!
# API call for LP-00366 was successful!
# API call for LP-00367 was successful!
# API call for LP-00368 was successful!
# API call for LP-00369 was successful!
# API call for LP-00371 was successful!
# API call for LP-00373 was successful!
# API call for LP-00375 was successful!
# API call for LP-00377 was successful!
# API call for LP-00379 was successful!
# API call for LP-00380 was successful!
# API call for LP-00384 was successful!
# API call for LP-00385 was successful!
# API call for LP-00387 failed with status code 404.
# API call for LP-00389 was successful!
# API call for LP-00391 was successful!
# API call for LP-00392 was successful!
# API call for LP-00393 was successful!
# API call for LP-00398 was successful!
# API call for LP-00399 was successful!
# API call for LP-00400 was successful!
# API call for LP-00410 was successful!
# API call for LP-00415 was successful!
# API call for LP-00416 was successful!
# API call for LP-00417 was successful!
# API call for LP-00418 was successful!
# API call for LP-00420 was successful!
# API call for LP-00421 was successful!
# API call for LP-00422 was successful!
# API call for LP-00423 was successful!
# API call for LP-00424 was successful!
# API call for LP-00425 was successful!
# API call for LP-00426 was successful!
# API call for LP-00427 was successful!
# API call for LP-00429 was successful!
# API call for LP-00431 was successful!
# API call for LP-00433 was successful!
# API call for LP-00436 was successful!
# API call for LP-00437 was successful!
# API call for LP-00438 was successful!
# API call for LP-00439 was successful!
# API call for LP-00440 was successful!
# API call for LP-00442 was successful!
# API call for LP-00443 was successful!
# API call for LP-00444 was successful!
# API call for LP-00445 was successful!
# API call for LP-00446 was successful!
# API call for LP-00447 was successful!
# API call for LP-00448 was successful!
# API call for LP-00464 was successful!
# API call for LP-00466 failed with status code 404.
# API call for LP-00468 was successful!
# API call for LP-00471 was successful!
# API call for LP-00481 was successful!
# API call for LP-00487 was successful!
# API call for LP-00542 was successful!
# API call for LP-00543 was successful!
# API call for LP-00544 was successful!
# API call for LP-00545 was successful!
# API call for LP-00546 was successful!
# API call for LP-00547 failed with status code 404.
# API call for LP-00548 was successful!
# API call for LP-00551 was successful!
# API call for LP-00552 was successful!
# API call for LP-00553 was successful!
# API call for LP-00554 was successful!
# API call for LP-00555 was successful!
# API call for LP-00556 was successful!
# API call for LP-00557 was successful!
# API call for LP-00558 was successful!
# API call for LP-00559 was successful!
# API call for LP-00562 was successful!
# API call for LP-00563 was successful!
# API call for LP-00568 was successful!
# API call for LP-00579 was successful!
# API call for LP-00582 was successful!
# API call for LP-00583 was successful!
# API call for LP-00584 was successful!
# API call for LP-00587 was successful!
# API call for LP-00589 was successful!
# API call for LP-00590 was successful!
# API call for LP-00592 failed with status code 404.
# API call for LP-00593 was successful!
# API call for LP-00595 was successful!
# API call for LP-00597 was successful!
# API call for LP-00599 was successful!
# API call for LP-00601 was successful!
# API call for LP-00624 failed with status code 404.
# API call for LP-00628 was successful!
# API call for LP-00630 failed with status code 404.
# API call for LP-00632 was successful!
# API call for LP-00639 was successful!
# API call for LP-00643 was successful!
# API call for LP-00644 was successful!
# API call for LP-00645 was successful!
# API call for LP-00646 was successful!
# API call for LP-00656 was successful!
# API call for LP-00662 was successful!
# API call for LP-00664 was successful!
# API call for LP-00667 was successful!
# API call for LP-00668 was successful!
# API call for LP-00672 was successful!
# API call for LP-00673 was successful!
# API call for LP-00674 was successful!
# API call for LP-00675 was successful!
# API call for LP-00676 was successful!
# API call for LP-00677 was successful!
# API call for LP-00678 was successful!
# API call for LP-00679 was successful!
# API call for LP-00680 was successful!
# API call for LP-00681 was successful!
# API call for LP-00682 was successful!
# API call for LP-00683 was successful!
# API call for LP-00684 was successful!
# API call for LP-00685 was successful!
# API call for LP-00686 was successful!
# API call for LP-00687 was successful!
# API call for LP-00688 was successful!
# API call for LP-00689 was successful!
# API call for LP-00698 was successful!
# API call for LP-00699 was successful!
# API call for LP-00700 was successful!
# API call for LP-00702 was successful!
# API call for LP-00703 was successful!
# API call for LP-00704 was successful!
# API call for LP-00705 was successful!
# API call for LP-00706 was successful!
# API call for LP-00707 was successful!
# API call for LP-00708 was successful!
# API call for LP-00718 was successful!
# API call for LP-00729 was successful!
# API call for LP-00730 was successful!
# API call for LP-00731 was successful!
# API call for LP-00732 was successful!
# API call for LP-00733 failed with status code 404.
# API call for LP-00735 was successful!
# API call for LP-00737 was successful!
# API call for LP-00741 failed with status code 404.
# API call for LP-00742 was successful!
# API call for LP-00743 was successful!
# API call for LP-00744 was successful!
# API call for LP-00745 was successful!
# API call for LP-00746 was successful!
# API call for LP-00747 was successful!
# API call for LP-00748 was successful!
# API call for LP-00749 was successful!
# API call for LP-00769 was successful!
# API call for LP-00770 was successful!
# API call for LP-00771 was successful!
# API call for LP-00772 was successful!
# API call for LP-00773 was successful!
# API call for LP-00803 was successful!
# API call for LP-00805 was successful!
# API call for LP-00820 was successful!
# API call for LP-00821 was successful!
# API call for LP-00823 was successful!
# API call for LP-00824 was successful!
# API call for LP-00826 was successful!
# API call for LP-00827 was successful!
# API call for LP-00828 was successful!
# API call for LP-00829 was successful!
# API call for LP-00830 was successful!
# API call for LP-00831 was successful!
# API call for LP-00832 was successful!
# API call for LP-00833 was successful!
# API call for LP-00834 was successful!
# API call for LP-00835 was successful!
# API call for LP-00836 was successful!
# API call for LP-00837 was successful!
# API call for LP-00839 was successful!
# API call for LP-00841 was successful!
# API call for LP-00842 was successful!
# API call for LP-00844 was successful!
# API call for LP-00845 was successful!
# API call for LP-00846 was successful!
# API call for LP-00847 was successful!
# API call for LP-00848 was successful!
# API call for LP-00849 was successful!
# API call for LP-00850 was successful!
# API call for LP-00852 was successful!
# API call for LP-00853 was successful!
# API call for LP-00854 was successful!
# API call for LP-00856 was successful!
# API call for LP-00858 was successful!
# API call for LP-00859 was successful!
# API call for LP-00862 was successful!
# API call for LP-00863 was successful!
# API call for LP-00864 was successful!
# API call for LP-00865 was successful!
# API call for LP-00866 was successful!
# API call for LP-00867 was successful!
# API call for LP-00868 was successful!
# API call for LP-00869 was successful!
# API call for LP-00875 was successful!
# API call for LP-00876 was successful!
# API call for LP-00877 was successful!
# API call for LP-00878 was successful!
# API call for LP-00882 was successful!
# API call for LP-00883 was successful!
# API call for LP-00884 was successful!
# API call for LP-00891 was successful!
# API call for LP-00892 was successful!
# API call for LP-00894 was successful!
# API call for LP-00896 was successful!
# API call for LP-00898 was successful!
# API call for LP-00899 was successful!
# API call for LP-00900 was successful!
# API call for LP-00905 was successful!
# API call for LP-00907 failed with status code 404.
# API call for LP-00908 was successful!
# API call for LP-00909 was successful!
# API call for LP-00910 was successful!
# API call for LP-00911 was successful!
# API call for LP-00912 was successful!
# API call for LP-00917 was successful!
# API call for LP-00918 was successful!
# API call for LP-00920 was successful!
# API call for LP-00921 was successful!
# API call for LP-00924 was successful!
# API call for LP-00925 was successful!
# API call for LP-00927 was successful!
# API call for LP-00928 was successful!
# API call for LP-00930 was successful!
# API call for LP-00931 was successful!
# API call for LP-00932 was successful!
# API call for LP-00933 was successful!
# API call for LP-00934 was successful!
# API call for LP-00935 was successful!
# API call for LP-00936 was successful!
# API call for LP-00937 was successful!
# API call for LP-00938 was successful!
# API call for LP-00939 was successful!
# API call for LP-00940 was successful!
# API call for LP-00941 was successful!
# API call for LP-00942 was successful!
# API call for LP-00943 was successful!
# API call for LP-00944 was successful!
# API call for LP-00945 was successful!
# API call for LP-00946 was successful!
# API call for LP-00949 was successful!
# API call for LP-00950 was successful!
# API call for LP-00951 was successful!
# API call for LP-00952 was successful!
# API call for LP-00954 was successful!
# API call for LP-00957 was successful!
# API call for LP-00958 was successful!
# API call for LP-00959 was successful!
# API call for LP-00960 was successful!
# API call for LP-00961 was successful!
# API call for LP-00962 was successful!
# API call for LP-00963 was successful!
# API call for LP-00968 was successful!
# API call for LP-00969 was successful!
# API call for LP-00970 was successful!
# API call for LP-00971 was successful!
# API call for LP-00974 was successful!
# API call for LP-00975 was successful!
# API call for LP-00976 was successful!
# API call for LP-00977 was successful!
# API call for LP-00980 was successful!
# API call for LP-00981 was successful!
# API call for LP-00982 was successful!
# API call for LP-00983 was successful!
# API call for LP-00984 was successful!
# API call for LP-00985 was successful!
# API call for LP-00986 was successful!
# API call for LP-00987 was successful!
# API call for LP-00990 was successful!
# API call for LP-00991 was successful!
# API call for LP-00992 was successful!
# API call for LP-00993 was successful!
# API call for LP-00997 was successful!
# API call for LP-00999 was successful!
# API call for LP-01000 was successful!
# API call for LP-01002 was successful!
# API call for LP-01004 was successful!
# API call for LP-01005 was successful!
# API call for LP-01006 was successful!
# API call for LP-01007 was successful!
# API call for LP-01008 was successful!
# API call for LP-01009 was successful!
# API call for LP-01010 was successful!
# API call for LP-01011 was successful!
# API call for LP-01013 was successful!
# API call for LP-01014 was successful!
# API call for LP-01017 was successful!
# API call for LP-01019 was successful!
# API call for LP-01020 was successful!
# API call for LP-01021 was successful!
# API call for LP-01025 was successful!
# API call for LP-01026 was successful!
# API call for LP-01035 was successful!
# API call for LP-01036 was successful!
# API call for LP-01038 was successful!
# API call for LP-01039 was successful!
# API call for LP-01040 was successful!
# API call for LP-01041 was successful!
# API call for LP-01044 was successful!
# API call for LP-01045 was successful!
# API call for LP-01046 was successful!
# API call for LP-01047 was successful!
# API call for LP-01048 was successful!
# API call for LP-01049 was successful!
# API call for LP-01050 was successful!
# API call for LP-01052 was successful!
# API call for LP-01053 was successful!
# API call for LP-01056 was successful!
# API call for LP-01057 was successful!
# API call for LP-01058 was successful!
# API call for LP-01059 was successful!
# API call for LP-01060 was successful!
# API call for LP-01061 was successful!
# API call for LP-01062 was successful!
# API call for LP-01063 was successful!
# API call for LP-01064 was successful!
# API call for LP-01065 was successful!
# API call for LP-01066 was successful!
# API call for LP-01067 was successful!
# API call for LP-01068 was successful!
# API call for LP-01069 was successful!
# API call for LP-01070 was successful!
# API call for LP-01071 was successful!
# API call for LP-01072 was successful!
# API call for LP-01073 was successful!
# API call for LP-01074 was successful!
# API call for LP-01076 was successful!
# API call for LP-01077 was successful!
# API call for LP-01079 was successful!
# API call for LP-01080 was successful!
# API call for LP-01081 was successful!
# API call for LP-01082 was successful!
# API call for LP-01083 was successful!
# API call for LP-01084 was successful!
# API call for LP-01085 was successful!
# API call for LP-01086 was successful!
# API call for LP-01089 was successful!
# API call for LP-01091 was successful!
# API call for LP-01094 was successful!
# API call for LP-01100 was successful!
# API call for LP-01101 was successful!
# API call for LP-01102 was successful!
# API call for LP-01103 was successful!
# API call for LP-01104 was successful!
# API call for LP-01105 was successful!
# API call for LP-01107 was successful!
# API call for LP-01109 was successful!
# API call for LP-01112 was successful!
# API call for LP-01113 was successful!
# API call for LP-01116 was successful!
# API call for LP-01126 was successful!
# API call for LP-01127 was successful!
# API call for LP-01128 was successful!
# API call for LP-01129 was successful!
# API call for LP-01132 was successful!
# API call for LP-01133 was successful!
# API call for LP-01134 was successful!
# API call for LP-01135 was successful!
# API call for LP-01137 was successful!
# API call for LP-01138 was successful!
# API call for LP-01139 was successful!
# API call for LP-01140 was successful!
# API call for LP-01141 was successful!
# API call for LP-01142 was successful!
# API call for LP-01143 was successful!
# API call for LP-01144 was successful!
# API call for LP-01145 was successful!
# API call for LP-01146 was successful!
# API call for LP-01147 was successful!
# API call for LP-01148 was successful!
# API call for LP-01149 was successful!
# API call for LP-01150 was successful!
# API call for LP-01151 was successful!
# API call for LP-01152 was successful!
# API call for LP-01153 was successful!
# API call for LP-01154 was successful!
# API call for LP-01155 was successful!
# API call for LP-01156 was successful!
# API call for LP-01157 was successful!
# API call for LP-01158 was successful!
# API call for LP-01159 was successful!
# API call for LP-01160 was successful!
# API call for LP-01161 was successful!
# API call for LP-01162 was successful!
# API call for LP-01163 was successful!
# API call for LP-01164 was successful!
# API call for LP-01169 was successful!
# API call for LP-01170 was successful!
# API call for LP-01171 was successful!
# API call for LP-01172 was successful!
# API call for LP-01173 was successful!
# API call for LP-01174 was successful!
# API call for LP-01176 was successful!
# API call for LP-01177 failed with status code 404.
# API call for LP-01179 was successful!
# API call for LP-01194 was successful!
# API call for LP-01197 was successful!
# API call for LP-01201 was successful!
# API call for LP-01206 was successful!
# API call for LP-01207 was successful!
# API call for LP-01212 was successful!
# API call for LP-01213 was successful!
# API call for LP-01214 was successful!
# API call for LP-01217 was successful!
# API call for LP-01218 was successful!
# API call for LP-01222 was successful!
# API call for LP-01224 was successful!
# API call for LP-01225 was successful!
# API call for LP-01226 was successful!
# API call for LP-01227 was successful!
# API call for LP-01228 was successful!
# API call for LP-01229 was successful!
# API call for LP-01233 was successful!
# API call for LP-01234 was successful!
# API call for LP-01237 was successful!
# API call for LP-01239 was successful!
# API call for LP-01241 was successful!
# API call for LP-01242 was successful!
# API call for LP-01243 was successful!
# API call for LP-01245 was successful!
# API call for LP-01246 was successful!
# API call for LP-01254 was successful!
# API call for LP-01264 was successful!
# API call for LP-01265 was successful!
# API call for LP-01266 was successful!
# API call for LP-01267 was successful!
# API call for LP-01273 was successful!
# API call for LP-01274 was successful!
# API call for LP-01276 was successful!
# API call for LP-01277 was successful!
# API call for LP-01279 was successful!
# API call for LP-01280 was successful!
# API call for LP-01282 was successful!
# API call for LP-01283 was successful!
# API call for LP-01285 was successful!
# API call for LP-01287 was successful!
# API call for LP-01288 was successful!
# API call for LP-01289 was successful!
# API call for LP-01292 was successful!
# API call for LP-01293 was successful!
# API call for LP-01295 was successful!
# API call for LP-01297 was successful!
# API call for LP-01299 was successful!
# API call for LP-01304 was successful!
# API call for LP-01305 was successful!
# API call for LP-01309 was successful!
# API call for LP-01311 was successful!
# API call for LP-01313 was successful!
# API call for LP-01315 was successful!
# API call for LP-01317 was successful!
# API call for LP-01321 was successful!
# API call for LP-01323 was successful!
# API call for LP-01328 was successful!
# API call for LP-01333 was successful!
# API call for LP-01335 was successful!
# API call for LP-01338 was successful!
# API call for LP-01340 was successful!
# API call for LP-01346 was successful!
# API call for LP-01348 was successful!
# API call for LP-01350 was successful!
# API call for LP-01355 was successful!
# API call for LP-01357 was successful!
# API call for LP-01359 was successful!
# API call for LP-01368 was successful!
# API call for LP-01372 was successful!
# API call for LP-01374 was successful!
# API call for LP-01378 was successful!
# API call for LP-01389 was successful!
# API call for LP-01390 was successful!
# API call for LP-01395 was successful!
# API call for LP-01396 was successful!
# API call for LP-01398 was successful!
# API call for LP-01399 failed with status code 404.
# API call for LP-01401 was successful!
# API call for LP-01402 was successful!
# API call for LP-01407 was successful!
# API call for LP-01412 was successful!
# API call for LP-01415 was successful!
# API call for LP-01419 was successful!
# API call for LP-01423 was successful!
# API call for LP-01431 was successful!
# API call for LP-01432 was successful!
# API call for LP-01433 was successful!
# API call for LP-01436 was successful!
# API call for LP-01437 was successful!
# API call for LP-01438 was successful!
# API call for LP-01439 was successful!
# API call for LP-01440 was successful!
# API call for LP-01446 was successful!
# API call for LP-01447 was successful!
# API call for LP-01455 was successful!
# API call for LP-01458 was successful!
# API call for LP-01460 was successful!
# API call for LP-01504 was successful!
# API call for LP-01505 was successful!
# API call for LP-01506 was successful!
# API call for LP-01507 was successful!
# API call for LP-01512 was successful!
# API call for LP-01516 was successful!
# API call for LP-01517 was successful!
# API call for LP-01518 was successful!
# API call for LP-01519 was successful!
# API call for LP-01520 was successful!
# API call for LP-01521 was successful!
# API call for LP-01523 was successful!
# API call for LP-01529 was successful!
# API call for LP-01530 was successful!
# API call for LP-01533 was successful!
# API call for LP-01534 failed with status code 404.
# API call for LP-01536 was successful!
# API call for LP-01537 was successful!
# API call for LP-01538 was successful!
# API call for LP-01539 was successful!
# API call for LP-01540 was successful!
# API call for LP-01541 was successful!
# API call for LP-01542 was successful!
# API call for LP-01545 was successful!
# API call for LP-01546 was successful!
# API call for LP-01547 was successful!
# API call for LP-01552 was successful!
# API call for LP-01553 was successful!
# API call for LP-01555 was successful!
# API call for LP-01556 failed with status code 404.
# API call for LP-01557 was successful!
# API call for LP-01558 was successful!
# API call for LP-01561 was successful!
# API call for LP-01562 was successful!
# API call for LP-01563 was successful!
# API call for LP-01564 was successful!
# API call for LP-01566 was successful!
# API call for LP-01568 was successful!
# API call for LP-01571 was successful!
# API call for LP-01575 was successful!
# API call for LP-01578 was successful!
# API call for LP-01581 was successful!
# API call for LP-01582 was successful!
# API call for LP-01583 was successful!
# API call for LP-01585 was successful!
# API call for LP-01586 was successful!
# API call for LP-01587 was successful!
# API call for LP-01616 was successful!
# API call for LP-01618 was successful!
# API call for LP-01620 was successful!
# API call for LP-01621 was successful!
# API call for LP-01622 was successful!
# API call for LP-01623 was successful!
# API call for LP-01624 was successful!
# API call for LP-01625 was successful!
# API call for LP-01627 was successful!
# API call for LP-01628 was successful!
# API call for LP-01629 was successful!
# API call for LP-01630 was successful!
# API call for LP-01632 was successful!
# API call for LP-01633 was successful!
# API call for LP-01634 was successful!
# API call for LP-01636 was successful!
# API call for LP-01638 was successful!
# API call for LP-01639 was successful!
# API call for LP-01640 was successful!
# API call for LP-01644 was successful!
# API call for LP-01645 was successful!
# API call for LP-01648 was successful!
# API call for LP-01649 was successful!
# API call for LP-01650 was successful!
# API call for LP-01651 was successful!
# API call for LP-01652 was successful!
# API call for LP-01653 was successful!
# API call for LP-01654 was successful!
# API call for LP-01658 was successful!
# API call for LP-01659 was successful!
# API call for LP-01660 was successful!
# API call for LP-01661 was successful!
# API call for LP-01664 was successful!
# API call for LP-01667 was successful!
# API call for LP-01668 was successful!
# API call for LP-01669 was successful!
# API call for LP-01670 was successful!
# API call for LP-01672 was successful!
# API call for LP-01673 was successful!
# API call for LP-01674 was successful!
# API call for LP-01675 was successful!
# API call for LP-01676 was successful!
# API call for LP-01677 was successful!
# API call for LP-01678 was successful!
# API call for LP-01679 was successful!
# API call for LP-01680 was successful!
# API call for LP-01681 was successful!
# API call for LP-01682 was successful!
# API call for LP-01683 was successful!
# API call for LP-01684 was successful!
# API call for LP-01685 was successful!
# API call for LP-01686 was successful!
# API call for LP-01687 was successful!
# API call for LP-01689 was successful!
# API call for LP-01708 was successful!
# API call for LP-01710 was successful!
# API call for LP-01715 was successful!
# API call for LP-01716 was successful!
# API call for LP-01717 was successful!
# API call for LP-01718 was successful!
# API call for LP-01719 was successful!
# API call for LP-01725 was successful!
# API call for LP-01745 was successful!
# API call for LP-01747 was successful!
# API call for LP-01749 was successful!
# API call for LP-01751 was successful!
# API call for LP-01753 was successful!
# API call for LP-01756 was successful!
# API call for LP-01758 was successful!
# API call for LP-01759 was successful!
# API call for LP-01763 was successful!
# API call for LP-01764 was successful!
# API call for LP-01766 was successful!
# API call for LP-01770 was successful!
# API call for LP-01772 was successful!
# API call for LP-01773 was successful!
# API call for LP-01774 was successful!
# API call for LP-01790 was successful!
# API call for LP-01794 was successful!
# API call for LP-01795 was successful!
# API call for LP-01796 was successful!
# API call for LP-01798 was successful!
# API call for LP-01805 was successful!
# API call for LP-01808 was successful!
# API call for LP-01809 was successful!
# API call for LP-01810 was successful!
# API call for LP-01812 was successful!
# API call for LP-01814 was successful!
# API call for LP-01815 was successful!
# API call for LP-01816 failed with status code 404.
# API call for LP-01817 was successful!
# API call for LP-01818 was successful!
# API call for LP-01819 was successful!
# API call for LP-01836 was successful!
# API call for LP-01837 was successful!
# API call for LP-01838 was successful!
# API call for LP-01839 was successful!
# API call for LP-01840 was successful!
# API call for LP-01841 was successful!
# API call for LP-01842 was successful!
# API call for LP-01843 was successful!
# API call for LP-01844 was successful!
# API call for LP-01845 was successful!
# API call for LP-01846 was successful!
# API call for LP-01848 was successful!
# API call for LP-01849 was successful!
# API call for LP-01851 was successful!
# API call for LP-01859 was successful!
# API call for LP-01860 was successful!
# API call for LP-01861 was successful!
# API call for LP-01862 was successful!
# API call for LP-01863 was successful!
# API call for LP-01870 was successful!
# API call for LP-01871 was successful!
# API call for LP-01872 was successful!
# API call for LP-01873 was successful!
# API call for LP-01875 was successful!
# API call for LP-01876 was successful!
# API call for LP-01877 was successful!
# API call for LP-01886 was successful!
# API call for LP-01887 was successful!
# API call for LP-01888 was successful!
# API call for LP-01889 was successful!
# API call for LP-01891 was successful!
# API call for LP-01892 was successful!
# API call for LP-01895 was successful!
# API call for LP-01905 was successful!
# API call for LP-01907 was successful!
# API call for LP-01912 was successful!
# API call for LP-01914 was successful!
# API call for LP-01915 was successful!
# API call for LP-01920 was successful!
# API call for LP-01923 was successful!
# API call for LP-01924 was successful!
# API call for LP-01925 failed with status code 404.
# API call for LP-01926 was successful!
# API call for LP-01927 was successful!
# API call for LP-01928 was successful!
# API call for LP-01930 was successful!
# API call for LP-01931 was successful!
# API call for LP-01932 was successful!
# API call for LP-01933 was successful!
# API call for LP-01934 was successful!
# API call for LP-01935 was successful!
# API call for LP-01936 was successful!
# API call for LP-01937 was successful!
# API call for LP-01939 was successful!
# API call for LP-01940 was successful!
# API call for LP-01941 was successful!
# API call for LP-01942 was successful!
# API call for LP-01943 was successful!
# API call for LP-01944 was successful!
# API call for LP-01945 was successful!
# API call for LP-01947 was successful!
# API call for LP-01948 was successful!
# API call for LP-01949 was successful!
# API call for LP-01950 was successful!
# API call for LP-01951 was successful!
# API call for LP-01953 was successful!
# API call for LP-01954 was successful!
# API call for LP-01955 was successful!
# API call for LP-01956 failed with status code 404.
# API call for LP-01958 was successful!
# API call for LP-01959 was successful!
# API call for LP-01960 was successful!
# API call for LP-01962 was successful!
# API call for LP-01963 was successful!
# API call for LP-01964 was successful!
# API call for LP-01965 was successful!
# API call for LP-01966 was successful!
# API call for LP-01967 was successful!
# API call for LP-01968 was successful!
# API call for LP-01969 was successful!
# API call for LP-01971 was successful!
# API call for LP-01972 was successful!
# API call for LP-01973 was successful!
# API call for LP-01975 was successful!
# API call for LP-01977 was successful!
# API call for LP-01978 failed with status code 404.
# API call for LP-01980 was successful!
# API call for LP-01981 was successful!
# API call for LP-01983 was successful!
# API call for LP-01984 was successful!
# API call for LP-01986 was successful!
# API call for LP-01987 was successful!
# API call for LP-01988 was successful!
# API call for LP-01989 was successful!
# API call for LP-01990 was successful!
# API call for LP-01991 was successful!
# API call for LP-01992 was successful!
# API call for LP-01993 was successful!
# API call for LP-01994 was successful!
# API call for LP-01995 was successful!
# API call for LP-01996 was successful!
# API call for LP-01997 was successful!
# API call for LP-01998 was successful!
# API call for LP-01999 was successful!
# API call for LP-02000 was successful!
# API call for LP-02004 was successful!
# API call for LP-02005 was successful!
# API call for LP-02006 was successful!
# API call for LP-02007 was successful!
# API call for LP-02008 was successful!
# API call for LP-02009 was successful!
# API call for LP-02010 was successful!
# API call for LP-02011 was successful!
# API call for LP-02012 was successful!
# API call for LP-02013 was successful!
# API call for LP-02014 was successful!
# API call for LP-02015 was successful!
# API call for LP-02016 was successful!
# API call for LP-02018 was successful!
# API call for LP-02019 was successful!
# API call for LP-02020 was successful!
# API call for LP-02021 was successful!
# API call for LP-02022 was successful!
# API call for LP-02023 was successful!
# API call for LP-02024 was successful!
# API call for LP-02025 was successful!
# API call for LP-02026 was successful!
# API call for LP-02027 was successful!
# API call for LP-02028 was successful!
# API call for LP-02029 was successful!
# API call for LP-02030 was successful!
# API call for LP-02031 was successful!
# API call for LP-02032 was successful!
# API call for LP-02034 was successful!
# API call for LP-02035 was successful!
# API call for LP-02036 was successful!
# API call for LP-02037 was successful!
# API call for LP-02038 was successful!
# API call for LP-02041 was successful!
# API call for LP-02042 was successful!
# API call for LP-02043 was successful!
# API call for LP-02045 was successful!
# API call for LP-02046 was successful!
# API call for LP-02047 was successful!
# API call for LP-02048 was successful!
# API call for LP-02049 was successful!
# API call for LP-02050 was successful!
# API call for LP-02051 was successful!
# API call for LP-02052 was successful!
# API call for LP-02053 was successful!
# API call for LP-02054 was successful!
# API call for LP-02055 was successful!
# API call for LP-02056 was successful!
# API call for LP-02057 was successful!
# API call for LP-02058 was successful!
# API call for LP-02059 was successful!
# API call for LP-02060 was successful!
# API call for LP-02061 was successful!
# API call for LP-02062 was successful!
# API call for LP-02063 was successful!
# API call for LP-02065 was successful!
# API call for LP-02066 was successful!
# API call for LP-02067 was successful!
# API call for LP-02068 was successful!
# API call for LP-02069 was successful!
# API call for LP-02071 was successful!
# API call for LP-02072 was successful!
# API call for LP-02073 was successful!
# API call for LP-02074 was successful!
# API call for LP-02075 was successful!
# API call for LP-02076 was successful!
# API call for LP-02077 was successful!
# API call for LP-02078 was successful!
# API call for LP-02079 was successful!
# API call for LP-02080 was successful!
# API call for LP-02082 failed with status code 404.
# API call for LP-02083 was successful!
# API call for LP-02084 was successful!
# API call for LP-02085 was successful!
# API call for LP-02086 was successful!
# API call for LP-02087 was successful!
# API call for LP-02088 was successful!
# API call for LP-02089 was successful!
# API call for LP-02090 was successful!
# API call for LP-02091 was successful!
# API call for LP-02093 was successful!
# API call for LP-02094 was successful!
# API call for LP-02096 was successful!
# API call for LP-02098 was successful!
# API call for LP-02099 was successful!
# API call for LP-02100 was successful!
# API call for LP-02101 was successful!
# API call for LP-02106 was successful!
# API call for LP-02107 was successful!
# API call for LP-02108 was successful!
# API call for LP-02109 was successful!
# API call for LP-02110 was successful!
# API call for LP-02112 was successful!
# API call for LP-02113 was successful!
# API call for LP-02114 was successful!
# API call for LP-02115 was successful!
# API call for LP-02116 was successful!
# API call for LP-02117 was successful!
# API call for LP-02118 failed with status code 500.
# API call for LP-02121 was successful!
# API call for LP-02123 was successful!
# API call for LP-02124 was successful!
# API call for LP-02125 was successful!
# API call for LP-02126 was successful!
# API call for LP-02128 was successful!
# API call for LP-02130 was successful!
# API call for LP-02131 was successful!
# API call for LP-02133 was successful!
# API call for LP-02135 was successful!
# API call for LP-02137 was successful!
# API call for LP-02139 was successful!
# API call for LP-02141 was successful!
# API call for LP-02143 was successful!
# API call for LP-02144 was successful!
# API call for LP-02145 was successful!
# API call for LP-02146 was successful!
# API call for LP-02149 was successful!
# API call for LP-02150 was successful!
# API call for LP-02151 was successful!
# API call for LP-02152 was successful!
# API call for LP-02153 was successful!
# API call for LP-02154 was successful!
# API call for LP-02156 was successful!
# API call for LP-02157 was successful!
# API call for LP-02158 was successful!
# API call for LP-02160 was successful!
# API call for LP-02161 was successful!
# API call for LP-02162 was successful!
# API call for LP-02164 was successful!
# API call for LP-02165 was successful!
# API call for LP-02166 was successful!
# API call for LP-02167 was successful!
# API call for LP-02168 was successful!
# API call for LP-02169 was successful!
# API call for LP-02170 was successful!
# API call for LP-02171 was successful!
# API call for LP-02172 was successful!
# API call for LP-02175 was successful!
# API call for LP-02176 was successful!
# API call for LP-02178 was successful!
# API call for LP-02179 was successful!
# API call for LP-02185 was successful!
# API call for LP-02186 was successful!
# API call for LP-02188 was successful!
# API call for LP-02189 was successful!
# API call for LP-02190 was successful!
# API call for LP-02191 was successful!
# API call for LP-02192 was successful!
# API call for LP-02194 was successful!
# API call for LP-02195 was successful!
# API call for LP-02196 was successful!
# API call for LP-02197 was successful!
# API call for LP-02198 was successful!
# API call for LP-02200 was successful!
# API call for LP-02201 was successful!
# API call for LP-02202 failed with status code 500.
# API call for LP-02205 was successful!
# API call for LP-02207 was successful!
# API call for LP-02210 was successful!
# API call for LP-02211 was successful!
# API call for LP-02212 was successful!
# API call for LP-02213 was successful!
# API call for LP-02214 was successful!
# API call for LP-02215 was successful!
# API call for LP-02217 was successful!
# API call for LP-02218 was successful!
# API call for LP-02223 was successful!
# API call for LP-02224 was successful!
# API call for LP-02225 was successful!
# API call for LP-02226 was successful!
# API call for LP-02227 was successful!
# API call for LP-02231 was successful!
# API call for LP-02232 was successful!
# API call for LP-02234 was successful!
# API call for LP-02236 was successful!
# API call for LP-02237 was successful!
# API call for LP-02238 was successful!
# API call for LP-02240 was successful!
# API call for LP-02241 was successful!
# API call for LP-02242 was successful!
# API call for LP-02244 was successful!
# API call for LP-02246 was successful!
# API call for LP-02247 was successful!
# API call for LP-02249 was successful!
# API call for LP-02250 was successful!
# API call for LP-02252 was successful!
# API call for LP-02253 was successful!
# API call for LP-02259 was successful!
# API call for LP-02260 failed with status code 404.
# API call for LP-02261 was successful!
# API call for LP-02262 was successful!
# API call for LP-02263 was successful!
# API call for LP-02267 was successful!
# API call for LP-02268 was successful!
# API call for LP-02269 was successful!
# API call for LP-02270 was successful!
# API call for LP-02271 was successful!
# API call for LP-02272 was successful!
# API call for LP-02273 was successful!
# API call for LP-02274 was successful!
# API call for LP-02280 was successful!
# API call for LP-02281 was successful!
# API call for LP-02283 was successful!
# API call for LP-02284 was successful!
# API call for LP-02285 was successful!
# API call for LP-02286 was successful!
# API call for LP-02292 was successful!
# API call for LP-02294 was successful!
# API call for LP-02296 was successful!
# API call for LP-02297 was successful!
# API call for LP-02298 was successful!
# API call for LP-02299 was successful!
# API call for LP-02300 was successful!
# API call for LP-02304 was successful!
# API call for LP-02305 was successful!
# API call for LP-02308 was successful!
# API call for LP-02311 was successful!
# API call for LP-02312 was successful!
# API call for LP-02313 was successful!
# API call for LP-02315 was successful!
# API call for LP-02316 was successful!
# API call for LP-02317 was successful!
# API call for LP-02318 was successful!
# API call for LP-02320 was successful!
# API call for LP-02321 was successful!
# API call for LP-02322 was successful!
# API call for LP-02323 was successful!
# API call for LP-02325 was successful!
# API call for LP-02326 was successful!
# API call for LP-02327 was successful!
# API call for LP-02328 was successful!
# API call for LP-02329 was successful!
# API call for LP-02330 was successful!
# API call for LP-02331 was successful!
# API call for LP-02336 was successful!
# API call for LP-02337 was successful!
# API call for LP-02338 was successful!
# API call for LP-02340 was successful!
# API call for LP-02341 was successful!
# API call for LP-02342 was successful!
# API call for LP-02343 was successful!
# API call for LP-02344 was successful!
# API call for LP-02345 was successful!
# API call for LP-02346 was successful!
# API call for LP-02349 was successful!
# API call for LP-02350 was successful!
# API call for LP-02353 was successful!
# API call for LP-02354 was successful!
# API call for LP-02363 was successful!
# API call for LP-02367 was successful!
# API call for LP-02368 was successful!
# API call for LP-02369 was successful!
# API call for LP-02370 was successful!
# API call for LP-02374 was successful!
# API call for LP-02376 was successful!
# API call for LP-02377 was successful!
# API call for LP-02378 was successful!
# API call for LP-02379 was successful!
# API call for LP-02380 was successful!
# API call for LP-02381 was successful!
# API call for LP-02382 was successful!
# API call for LP-02383 was successful!
# API call for LP-02384 was successful!
# API call for LP-02385 was successful!
# API call for LP-02386 was successful!
# API call for LP-02387 was successful!
# API call for LP-02388 was successful!
# API call for LP-02389 was successful!
# API call for LP-02390 was successful!
# API call for LP-02391 was successful!
# API call for LP-02393 was successful!
# API call for LP-02395 was successful!
# API call for LP-02396 was successful!
# API call for LP-02397 was successful!
# API call for LP-02398 was successful!
# API call for LP-02399 was successful!
# API call for LP-02400 was successful!
# API call for LP-02401 was successful!
# API call for LP-02404 was successful!
# API call for LP-02406 was successful!
# API call for LP-02408 was successful!
# API call for LP-02410 was successful!
# API call for LP-02411 was successful!
# API call for LP-02412 was successful!
# API call for LP-02413 was successful!
# API call for LP-02414 was successful!
# API call for LP-02415 was successful!
# API call for LP-02416 was successful!
# API call for LP-02417 was successful!
# API call for LP-02418 was successful!
# API call for LP-02419 was successful!
# API call for LP-02420 was successful!
# API call for LP-02423 was successful!
# API call for LP-02424 was successful!
# API call for LP-02425 failed with status code 404.
# API call for LP-02427 was successful!
# API call for LP-02428 was successful!
# API call for LP-02429 was successful!
# API call for LP-02431 was successful!
# API call for LP-02432 was successful!
# API call for LP-02433 was successful!
# API call for LP-02435 was successful!
# API call for LP-02441 was successful!
# API call for LP-02447 was successful!
# API call for LP-02461 was successful!
# API call for LP-02466 was successful!
# API call for LP-02469 was successful!
# API call for LP-02471 was successful!
# API call for LP-02472 was successful!
# API call for LP-02473 was successful!
# API call for LP-02474 was successful!
# API call for LP-02476 was successful!
# API call for LP-02480 was successful!
# API call for LP-02481 was successful!
# API call for LP-02482 was successful!
# API call for LP-02486 was successful!
# API call for LP-02487 was successful!
# API call for LP-02490 was successful!
# API call for LP-02494 was successful!
# API call for LP-02495 was successful!
# API call for LP-02510 was successful!
# API call for LP-02515 was successful!
# API call for LP-02517 was successful!
# API call for LP-02518 was successful!
# API call for LP-02519 was successful!
# API call for LP-02520 was successful!
# API call for LP-02521 was successful!
# API call for LP-02522 was successful!
# API call for LP-02523 was successful!
# API call for LP-02524 was successful!
# API call for LP-02525 was successful!
# API call for LP-02526 was successful!
# API call for LP-02527 was successful!
# API call for LP-02528 was successful!
# API call for LP-02529 was successful!
# API call for LP-02530 was successful!
# API call for LP-02531 was successful!
# API call for LP-02533 was successful!
# API call for LP-02537 was successful!
# API call for LP-02538 was successful!
# API call for LP-02539 was successful!
# API call for LP-02540 was successful!
# API call for LP-02541 was successful!
# API call for LP-02542 was successful!
# API call for LP-02543 was successful!
# API call for LP-02544 was successful!
# API call for LP-02545 was successful!
# API call for LP-02548 was successful!
# API call for LP-02549 was successful!
# API call for LP-02554 failed with status code 404.
# API call for LP-02555 was successful!
# API call for LP-02556 was successful!
# API call for LP-02557 was successful!
# API call for LP-02559 was successful!
# API call for LP-02562 was successful!
# API call for LP-02564 was successful!
# API call for LP-02565 was successful!
# API call for LP-02568 was successful!
# API call for LP-02569 was successful!
# API call for LP-02570 was successful!
# API call for LP-02574 was successful!
# API call for LP-02575 was successful!
# API call for LP-02576 was successful!
# API call for LP-02577 was successful!
# API call for LP-02579 was successful!
# API call for LP-02580 was successful!
# API call for LP-02581 was successful!
# API call for LP-02582 was successful!
# API call for LP-02585 was successful!
# API call for LP-02586 was successful!
# API call for LP-02587 was successful!
# API call for LP-02593 was successful!
# API call for LP-02594 was successful!
# API call for LP-02595 was successful!
# API call for LP-02596 was successful!
# API call for LP-02597 was successful!
# API call for LP-02598 was successful!
# API call for LP-02600 was successful!
# API call for LP-02601 was successful!
# API call for LP-02602 was successful!
# API call for LP-02603 was successful!
# API call for LP-02605 was successful!
# API call for LP-02608 was successful!
# API call for LP-02609 was successful!
# API call for LP-02610 was successful!
# API call for LP-02611 was successful!
# API call for LP-02612 was successful!
# API call for LP-02613 was successful!
# API call for LP-02614 was successful!
# API call for LP-02615 was successful!
# API call for LP-02616 was successful!
# API call for LP-02617 was successful!
# API call for LP-02618 was successful!
# API call for LP-02619 was successful!
# API call for LP-02620 was successful!
# API call for LP-02626 was successful!
# API call for LP-02627 was successful!
# API call for LP-02628 was successful!
# API call for LP-02629 was successful!
# API call for LP-02630 was successful!
# API call for LP-02632 was successful!
# API call for LP-02633 was successful!
# API call for LP-02634 was successful!
# API call for LP-02635 was successful!
# API call for LP-02636 was successful!
# API call for LP-02637 was successful!
# API call for LP-02638 was successful!
# API call for LP-02639 was successful!
# API call for LP-02640 was successful!
# API call for LP-02641 was successful!
# API call for LP-02642 was successful!
